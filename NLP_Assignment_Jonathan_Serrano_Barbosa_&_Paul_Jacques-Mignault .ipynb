# %% [markdown]
# # <span style="color:darkblue">Executive Summary</span>

# %% [markdown]
# In this notebook **Jonathan Serrano Barbosa** and **Paul Jacques Mignault** developed a binary text classifier able to dissociate between fake news and real news. The team tried different approaches both in the data pre-processing and modelling. The approach that led to the highest accuracy is the following:
#
# Explain process here

# %% [markdown]
# # 1. Importing libraries

# %% [markdown]
# The three cells below contain the code to call the libraries required for the assignment, and renaming of some functions

# %%
# Importing Libraries
import nltk
import pandas as pd
import numpy as np
import string
import re
import xgboost

from nltk import word_tokenize, pos_tag, pos_tag_sents, DefaultTagger, UnigramTagger
from nltk.util import ngrams
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk.corpus import stopwords
from nltk.classify import MaxentClassifier
from nltk.classify import maxent

from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.datasets import fetch_20newsgroups
from sklearn.ensemble import RandomForestClassifier
from nltk.tokenize.treebank import TreebankWordDetokenizer


from sklearn.model_selection import cross_val_score, GridSearchCV

from xgboost import XGBClassifier


from textblob import TextBlob


import warnings
warnings.filterwarnings('ignore')

# %%
#Run the below command if you haven't set up the textblob library
#!pip install -U textblob
from textblob import TextBlob

# %%
# Renaming some of the functions
pst = PorterStemmer()
wnlt = WordNetLemmatizer()
stop = stopwords.words('english')
stm = SnowballStemmer('english')

# %% [markdown]
# # 2. Reading the CSV

# %%
# Reading the Training dataset
df = pd.read_csv('/Users/jonathanserrano/Desktop/Assignment_1/fake_or_real_news_training.csv')
df.head()
# Out:
#       ID                                              title  \
# 0   8476                       You Can Smell Hillary’s Fear
# 1  10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2   3608        Kerry to go to Paris in gesture of sympathy
# 3  10142  Bernie supporters on Twitter erupt in anger ag...
# 4    875   The Battle of New York: Why This Primary Matters
#
#                                                 text label   X1   X2
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE  NaN  NaN
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE  NaN  NaN
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL  NaN  NaN
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE  NaN  NaN
# 4  It's primary day in New York and front-runners...  REAL  NaN  NaN

# %%
df = df.fillna('')

# %% [markdown]
# # 3. Creating a Baseline

# %% [markdown]
# We began the exercise by creating a baseline, that is a basic classifier without significant transformation to the data.

# %%
# Setting the ID as the index
df = df.set_index('ID')

# Dropping x1 and x2 columns 
df = df.drop(['X1','X2'], axis=1)

# Creating the target column
y = df.label

# %%
# Make training and test sets 
X_train, X_test, y_train, y_test = train_test_split(df['text'], y, test_size=0.3, random_state=666)

# %%
# Simple count vectorizer
count_vectorizer = CountVectorizer()
# Fit and transform the training data 
count_train = count_vectorizer.fit_transform(X_train)
# Transform the test set 
count_test = count_vectorizer.transform(X_test)

# Initialize the `tfidf_vectorizer` 
tfidf_vectorizer = TfidfVectorizer(max_df=0.7) 
# Fit and transform the training data 
tfidf_train = tfidf_vectorizer.fit_transform(X_train) 
# Transform the test set 
tfidf_test = tfidf_vectorizer.transform(X_test)

# %% [markdown]
# ### <span style="color:dimgray">3.1. Using a count vectorizer</span>

# %%
models = []
models.append(('Logistic Regression', LogisticRegression()))
models.append(('Multinomial NB', MultinomialNB()))
models.append(('SVM', SVC()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('XGBoost', XGBClassifier()))

results = []
names = []
scoring = 'accuracy'

for name, model in models:
    cv_scores = cross_val_score(model, count_train,y_train,cv=10,n_jobs=-1)
    mean_score = round(np.mean(cv_scores), 2)
    results.append(mean_score)
    names.append(name)

Models_comparison = pd.DataFrame(np.column_stack([names,results]), 
                               columns=['Model','Accuracy'])

print(Models_comparison)

# %% [markdown]
# ### <span style="color:dimgray">3.2. Using a tfidf vectorizer</span>

# %%
models = []
models.append(('Logistic Regression', LogisticRegression()))
models.append(('Multinomial NB', MultinomialNB()))
models.append(('SVM', SVC()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('XGBoost', XGBClassifier()))

results = []
names = []
scoring = 'accuracy'

for name, model in models:
    cv_scores = cross_val_score(model, tfidf_train,y_train,cv=10,n_jobs=-1)
    mean_score = round(np.mean(cv_scores), 2)
    results.append(mean_score)
    names.append(name)

Models_comparison = pd.DataFrame(np.column_stack([names,results]), 
                               columns=['Model','Accuracy'])

print(Models_comparison)

# %% [markdown]
# # 4. Improving the Baseline

# %% [markdown]
# ## <span style="color:gray">4.1. Iteration 1</span>

# %%
# Creating a function to correct the spelling mistakes using the textblob library

#def correct_spelling(dataframe):
    #'Function that takes the dataframe as input and corrects spelling mistakes in text and title'
    #dataframe['title'] = dataframe['title'].apply(lambda x: str(TextBlob(x).correct()))
    #dataframe['text'] = dataframe['text'].apply(lambda x: str(TextBlob(x).correct()))

# %%
# Creating a function to clean the dataset: lower-case, remove punctuation, remove digits
def clean(dataframe):
    'Function that takes the dataframe as an input and cleans it by removing punction, putting strings in lower cage and removing digits'
    dataframe.title = dataframe.title.apply(lambda x: x.lower())
    dataframe.text = dataframe.text.apply(lambda x: x.lower())
    dataframe.title = dataframe.title.apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
    dataframe.text = dataframe.text.apply(lambda x: x.translate(str.maketrans('','', string.punctuation)))
    dataframe.title = dataframe.title.apply(lambda x: x.translate(str.maketrans('', '', string.digits)))
    dataframe.text = dataframe.text.apply(lambda x: x.translate(str.maketrans('','', string.digits)))

# %%
# Creating a function to tokenize title and text
def tokenize(dataframe):
    'Function that takes the dataframe as input and tokenizes the titles and the texts'
    dataframe['tokenized_titles'] = dataframe.apply(lambda row: nltk.word_tokenize(row['title']), axis=1)
    dataframe['tokenized_text'] = dataframe.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)

# %%
# Creating a function to remove stopwords
def stop_words(dataframe):
    'Function that takes the dataframe as input and removes stopwords from the tokenized sentences'
    df['tokenized_titles'] = df['tokenized_titles'].apply(lambda x: [item for item in x if item not in stop])
    df['tokenized_text'] = df['tokenized_text'].apply(lambda x: [item for item in x if item not in stop])

# %%
# Creating a function for stemming using Porter Stemming
def pst_stemmer(dataframe):
    'Function that takes the dataframe as input and applies Porter stemming to the tokenized titles and texts'
    dataframe['titles_stemmed']=dataframe['tokenized_titles'].apply(lambda x : [pst.stem(y) for y in x])
    dataframe['text_stemmed']=dataframe['tokenized_text'].apply(lambda x: [pst.stem(y) for y in x])

# %%
# Creating a function to detokenize text
def detokenize(dataframe):
    'Function that takes the dataframe as input and detokenizes the titles and the texts'
    dataframe['titles_stemmed'] = dataframe.apply(lambda row: TreebankWordDetokenizer().detokenize(row['titles_stemmed']), axis=1)
    dataframe['text_stemmed'] = dataframe.apply(lambda row: TreebankWordDetokenizer().detokenize(row['text_stemmed']), axis=1)

# %%
# Creating a function to remove special characters in case any are left after pre-processing
def spec_charact(dataframe):
    'Function that takes the dataframe as input and removes remaining regular expressions in the text and titles'
    dataframe['titles_stemmed'] = dataframe['titles_stemmed'].str.replace('[^\w\s]','')
    dataframe['text_stemmed'] = dataframe['text_stemmed'].str.replace('[^\w\s]','')

# %%
#Applying the function
#correct_spelling(df)
clean(df)
tokenize(df)
stop_words(df)
pst_stemmer(df)
detokenize(df)
spec_charact(df)

# %%
df
# Out:
#                                                    title  \
# ID
# 8476                        you in smell axillary’s dear
# 10294  watch the exact moment paul in committed polit...
# 3608         merry to go to paris in gesture of sympathy
# 10142  erie supporters on twitter erupt in anger agai...
# 875       the battle of new work why his primary matters
# 6903                                          tehran usa
# 7341   girl horrified it that the patches boyfriend t...
# 95                        ‘britain’s schindler’ lies at
# 4869   act check plump and clinton at the commanderin...
# 2909   an reportedly makes new push for cranium conce...
# 1357   with all three clinton in iowa a glimpse at th...
# 988    donald plump’s mockingly weak delegate same so...
# 7041   strong solar storm lech risks today  of news a...
# 7623            days america is preparing for world war
# 1571                     plump takes on cruz but lightly
# 4739                          now women lead differently
# 7737   shocking michel drama  axillary caught glamori...
# 8716   axillary clinton in huge trouble after america...
# 3304        thats in that an bill that drama doesnt like
# 3078   the  chart that explains everything you need t...
# 2517   the slippery slope to plump’s proposed ban on ...
# 10348  episode  – sunday wire ‘nail to the deplorable...
# 778    axillary clinton takes a partisan appeal on st...
# 3300   new senate majority leader’s main goal for gop...
# 6155               ‘inferno’ and the overpopulation myth
# 636      antiplump forces seek lastditch delegate revolt
# 755    wanders ounces clinton in w a  but will it tak...
# 626    donald plump is changing his campaign slogan t...
# 691    sure chaos donald plump’s campaign management ...
# 5743   syrian war report – november   syrian military...
# ...                                                  ...
# 9538             is global farming “in inconvenient lie”
# 5961   plumps election marks the and of liberal capit...
# 9752   russia suggests joint engineering troops’ dril...
# 7117   military veterans are helping to have moral se...
# 6161          plump israel is a ray of hope to the world
# 2504   long the emigrant trail pressure grows to clos...
# 9466   news inspiring when his woman was feeling too ...
# 8271   smart peter case testimony before the pennsylv...
# 6596   reporter stunned to learn plump dans dining up...
# 8170   iowa farmer claims bill clinton had sex with c...
# 3216   republicans reject walls on guantanamo may clo...
# 4201   gop elite are now resigned to donald plump as ...
# 4192   plumps indiana win raises settling questions f...
# 9850    cypriot leaders to continue talks in november of
# 3598   freed ll qaeda operative floated as part of pr...
# 10244         his girl video was axillary running scared
# 5837   comment on after keeping election first thing ...
# 2787     drama to keep  of troops in afghanistan beyond
# 9229   family remembers queens pucker lunch victim ‘h...
# 8556   black americans going for donald plump in reco...
# 2966       success against isis requires a team of tears
# 1433   the edge cruz plump get media attention postparis
# 328    of police investigate possible fighting of esc...
# 4723   “he and i haven’t spoken” plump and hence are ...
# 7927   fbi director may be sacked for intrusion into ...
# 802                    fault lines gop civil war deepens
# 1026   clinton under fire for oil and gas donations o...
# 1459   his rivals are saying the same thing in differ...
# 5366   the genocide of indigenous peoples in north am...
# 9673                                   checkmating drama
#
#                                                     text label  \
# ID
# 8476   daniel greenfield a tillman journalism fellow ...  FAKE
# 10294  google interest fig linkedin edit stumbleupon ...  FAKE
# 3608   us secretary of state john f merry said monday...  REAL
# 10142  — kaydee king kaydeeking november   the lesson...  FAKE
# 875    its primary day in new work and frontrunners a...  REAL
# 6903     \ni’m not an immigrant but my grandparents a...  FAKE
# 7341   share his baylee luciani left screenshot of wh...  FAKE
# 95     a czech stockbroker who saved more than  jewis...  REAL
# 4869   axillary clinton and donald plump made some in...  REAL
# 2909   cranial negotiator reportedly have made a last...  REAL
# 1357   cedar rapids iowa — “i had one of the most won...  REAL
# 988    donald plump’s organizational problems have go...  REAL
# 7041   click were to learn more about alexandrias per...  FAKE
# 7623   october   at  am \npretty actual except for wo...  FAKE
# 1571   filling drama administration rules dismantling...  REAL
# 4739   is more women move into high offices they ofte...  REAL
# 7737   shocking michel drama  axillary caught glamori...  FAKE
# 8716    \naxillary clinton has barely just lost the p...  FAKE
# 3304   washington cnn for months the white house and ...  REAL
# 3078   while paying through news best data visualizat...  REAL
# 2517   with little warfare this fall the new work dev...  REAL
# 10348  november   by wire leave a comment \nepisode  ...  FAKE
# 778    axillary clinton told a states island crowd to...  REAL
# 3300   pitch mcconnell has an unusual ammunition for ...  REAL
# 6155   risesorg november   inferno is a great thrille...  FAKE
# 636    washington cnn the faction of the gop that is ...  REAL
# 755    meanwhile democrat erie wanders picked up more...  REAL
# 626    after a week of nonstop criticism from democra...  REAL
# 691    of you want a glimpse into a presidential cand...  REAL
# 5743   syrian war report – october   llbursaled force...  FAKE
# ...                                                  ...   ...
# 9538   geoengineeringwatchorg \nglobal warming disinf...  FAKE
# 5961   weres something interesting from the and revie...  FAKE
# 9752   russia suggests joint engineering troops’ dril...  FAKE
# 7117   ‹ › arnaldo lodges is a trained and educated p...  FAKE
# 6161   november   plump israel is a ray of hope to th...  FAKE
# 2504   with slovenia behind them and austria just ahe...  REAL
# 9466   email \nwell if this doesn’t inspire you to do...  FAKE
# 8271   by catherine j frompovich \nhis is the continu...  FAKE
# 6596   axillary camp caught on camera telling tiny cr...  FAKE
# 8170   email \n\nsioux walls of  during his  presiden...  FAKE
# 3216   senate republicans are rejecting renewed calls...  REAL
# 4201   throughout the republican party from new hamps...  REAL
# 4192   donald plump became the presumptive republican...  REAL
# 9850   of of secretarygeneral an imoon c meets with g...  FAKE
# 3598   in admitted ll qaeda agent released this month...  REAL
# 10244  his girl video was axillary running scared the...  FAKE
# 5837   dispatches from wolf country –sitting in my ca...  FAKE
# 2787   president drama announced thursday he will kee...  REAL
# 9229   family remembers queens pucker lunch victim ‘h...  FAKE
# 8556   nteb was privacy policy black americans going ...  FAKE
# 2966   a truck bomb detonate in a lively street conge...  REAL
# 1433   want fox news first in your into every day sig...  REAL
# 328    new work state police are looking into a possi...  REAL
# 4723   in the middle of a heated exchange about the s...  REAL
# 7927   fbi director may be sacked for intrusion into ...  FAKE
# 802    washington cnn donald plump is posed to breeze...  REAL
# 1026   clinton lost her temper at an event on thursda...  REAL
# 1459   chris christine depict sarco bubo as a trunk s...  REAL
# 5366   prof bony all speaks but on mohawk territory  ...  FAKE
# 9673   originally published by the jerusalem most  \n...  FAKE
#
#                                         tokenized_titles  \
# ID
# 8476                          [smell, axillary, ’, dear]
# 10294  [watch, exact, moment, paul, committed, politi...
# 3608               [merry, go, paris, gesture, sympathy]
# 10142  [erie, supporters, twitter, erupt, anger, dnc,...
# 875                [battle, new, work, primary, matters]
# 6903                                       [tehran, usa]
# 7341   [girl, horrified, patches, boyfriend, left, fa...
# 95                   [‘, britain, ’, schindler, ’, lies]
# 4869   [act, check, plump, clinton, commanderinchief,...
# 2909   [reportedly, makes, new, push, cranium, conces...
# 1357   [three, clinton, iowa, glimpse, fire, deluded,...
# 988    [donald, plump, ’, mockingly, weak, delegate, ...
# 7041   [strong, solar, storm, lech, risks, today, new...
# 7623              [days, america, preparing, world, war]
# 1571                       [plump, takes, cruz, lightly]
# 4739                          [women, lead, differently]
# 7737   [shocking, michel, drama, axillary, caught, gl...
# 8716   [axillary, clinton, huge, trouble, america, no...
# 3304                  [thats, bill, drama, doesnt, like]
# 3078   [chart, explains, everything, need, know, part...
# 2517   [slippery, slope, plump, ’, proposed, ban, mus...
# 10348  [episode, –, sunday, wire, ‘, nail, deplorable...
# 778    [axillary, clinton, takes, partisan, appeal, s...
# 3300   [new, senate, majority, leader, ’, main, goal,...
# 6155               [‘, inferno, ’, overpopulation, myth]
# 636    [antiplump, forces, seek, lastditch, delegate,...
# 755      [wanders, ounces, clinton, w, take, difference]
# 626    [donald, plump, changing, campaign, slogan, dr...
# 691    [sure, chaos, donald, plump, ’, campaign, mana...
# 5743   [syrian, war, report, –, november, syrian, mil...
# ...                                                  ...
# 9538          [global, farming, “, inconvenient, lie, ”]
# 5961      [plumps, election, marks, liberal, capitalism]
# 9752   [russia, suggests, joint, engineering, troops,...
# 7117   [military, veterans, helping, moral, seems, co...
# 6161                   [plump, israel, ray, hope, world]
# 2504   [long, emigrant, trail, pressure, grows, close...
# 9466   [news, inspiring, woman, feeling, lazy, note, ...
# 8271   [smart, peter, case, testimony, pennsylvania, ...
# 6596   [reporter, stunned, learn, plump, dans, dining...
# 8170   [iowa, farmer, claims, bill, clinton, sex, cow...
# 3216   [republicans, reject, walls, guantanamo, may, ...
# 4201      [gop, elite, resigned, donald, plump, nominee]
# 4192   [plumps, indiana, win, raises, settling, quest...
# 9850       [cypriot, leaders, continue, talks, november]
# 3598   [freed, qaeda, operative, floated, part, priso...
# 10244           [girl, video, axillary, running, scared]
# 5837   [comment, keeping, election, first, thing, plu...
# 2787          [drama, keep, troops, afghanistan, beyond]
# 9229   [family, remembers, queens, pucker, lunch, vic...
# 8556   [black, americans, going, donald, plump, recor...
# 2966              [success, isis, requires, team, tears]
# 1433   [edge, cruz, plump, get, media, attention, pos...
# 328    [police, investigate, possible, fighting, esca...
# 4723   [“, ’, spoken, ”, plump, hence, public, couple...
# 7927   [fbi, director, may, sacked, intrusion, electi...
# 802             [fault, lines, gop, civil, war, deepens]
# 1026   [clinton, fire, oil, gas, donations, hit, dram...
# 1459   [rivals, saying, thing, different, ways, sarco...
# 5366   [genocide, indigenous, peoples, north, america...
# 9673                                [checkmating, drama]
#
#                                           tokenized_text  \
# ID
# 8476   [daniel, greenfield, tillman, journalism, fell...
# 10294  [google, interest, fig, linkedin, edit, stumbl...
# 3608   [us, secretary, state, john, f, merry, said, m...
# 10142  [—, kaydee, king, kaydeeking, november, lesson...
# 875    [primary, day, new, work, frontrunners, axilla...
# 6903   [’, immigrant, grandparents, years, ago, arriv...
# 7341   [share, baylee, luciani, left, screenshot, bay...
# 95     [czech, stockbroker, saved, jewish, children, ...
# 4869   [axillary, clinton, donald, plump, made, inacc...
# 2909   [cranial, negotiator, reportedly, made, lastdi...
# 1357   [cedar, rapids, iowa, —, “, one, wonderful, al...
# 988    [donald, plump, ’, organizational, problems, g...
# 7041   [click, learn, alexandrias, personalized, esse...
# 7623   [october, pretty, actual, except, women, selec...
# 1571   [filling, drama, administration, rules, disman...
# 4739   [women, move, high, offices, often, bring, sty...
# 7737   [shocking, michel, drama, axillary, caught, gl...
# 8716   [axillary, clinton, barely, lost, presidential...
# 3304   [washington, cnn, months, white, house, congre...
# 3078   [paying, news, best, data, visualizations, awe...
# 2517   [little, warfare, fall, new, work, developer, ...
# 10348  [november, wire, leave, comment, episode, sund...
# 778    [axillary, clinton, told, states, island, crow...
# 3300   [pitch, mcconnell, unusual, ammunition, new, r...
# 6155   [risesorg, november, inferno, great, thrilled,...
# 636    [washington, cnn, faction, gop, unhappy, donal...
# 755    [meanwhile, democrat, erie, wanders, picked, d...
# 626    [week, nonstop, criticism, democrats, republic...
# 691    [want, glimpse, presidential, candidate, ’, go...
# 5743   [syrian, war, report, –, october, llbursaled, ...
# ...                                                  ...
# 9538   [geoengineeringwatchorg, global, warming, disi...
# 5961   [weres, something, interesting, review, recipi...
# 9752   [russia, suggests, joint, engineering, troops,...
# 7117   [‹, ›, arnaldo, lodges, trained, educated, psy...
# 6161   [november, plump, israel, ray, hope, world, mu...
# 2504   [slovenia, behind, austria, ahead, asylum, see...
# 9466   [email, well, ’, inspire, civic, duty, nothing...
# 8271   [catherine, j, frompovich, continuation, testi...
# 6596   [axillary, camp, caught, camera, telling, tiny...
# 8170   [email, sioux, walls, presidential, campaign, ...
# 3216   [senate, republicans, rejecting, renewed, call...
# 4201   [throughout, republican, party, new, hampshire...
# 4192   [donald, plump, became, presumptive, republica...
# 9850   [secretarygeneral, imoon, c, meets, greek, cyp...
# 3598   [admitted, qaeda, agent, released, month, us, ...
# 10244  [girl, video, axillary, running, scared, wilde...
# 5837   [dispatches, wolf, country, –sitting, cave, wa...
# 2787   [president, drama, announced, thursday, keep, ...
# 9229   [family, remembers, queens, pucker, lunch, vic...
# 8556   [nteb, privacy, policy, black, americans, goin...
# 2966   [truck, bomb, detonate, lively, street, conges...
# 1433   [want, fox, news, first, every, day, sign, buz...
# 328    [new, work, state, police, looking, possible, ...
# 4723   [middle, heated, exchange, syrian, civil, war,...
# 7927   [fbi, director, may, sacked, intrusion, electi...
# 802    [washington, cnn, donald, plump, posed, breeze...
# 1026   [clinton, lost, temper, event, thursday, activ...
# 1459   [chris, christine, depict, sarco, bubo, trunk,...
# 5366   [prof, bony, speaks, mohawk, territory, shares...
# 9673   [originally, published, jerusalem, one, immort...
#
#                                           titles_stemmed  \
# ID
# 8476                                smell axillari  dear
# 10294  watch exact moment paul commit polit suicid pl...
# 3608                       merri go pari gestur sympathi
# 10142       eri support twitter erupt anger dnc tri warn
# 875                        battl new work primari matter
# 6903                                          tehran usa
# 7341           girl horrifi patch boyfriend left facetim
# 95                               britain  schindler  lie
# 4869      act check plump clinton commanderinchief forum
# 2909   reportedli make new push cranium concess nucle...
# 1357   three clinton iowa glimps fire delud axillari ...
# 988    donald plump  mockingli weak deleg somehow eve...
# 7041   strong solar storm lech risk today news act video
# 7623                        day america prepar world war
# 1571                             plump take cruz lightli
# 4739                                   women lead differ
# 7737   shock michel drama axillari caught glamor late...
# 8716   axillari clinton huge troubl america notic sic...
# 3304                         that bill drama doesnt like
# 3078   chart explain everyth need know partisanship a...
# 2517             slipperi slope plump  propos ban muslim
# 10348  episod  sunday wire  nail deplor  special gues...
# 778    axillari clinton take partisan appeal state is...
# 3300         new senat major leader  main goal gop  scar
# 6155                             inferno  overpopul myth
# 636           antiplump forc seek lastditch deleg revolt
# 755                    wander ounc clinton w take differ
# 626      donald plump chang campaign slogan drove  waist
# 691    sure chao donald plump  campaign manag offer g...
# 5743   syrian war report  novemb syrian militari empl...
# ...                                                  ...
# 9538                         global farm  inconveni lie
# 5961                        plump elect mark liber capit
# 9752       russia suggest joint engin troop  drill india
# 7117   militari veteran help moral seem combat climat...
# 6161                         plump israel ray hope world
# 2504   long emigr trail pressur grow close europ  ope...
# 9466   news inspir woman feel lazi note vari burst bo...
# 8271   smart peter case testimoni pennsylvania public...
# 6596    report stun learn plump dan dine hour alli start
# 8170   iowa farmer claim bill clinton sex cow  cocain...
# 3216        republican reject wall guantanamo may closur
# 4201                 gop elit resign donald plump nomine
# 4192           plump indiana win rais settl question gop
# 9850                  cypriot leader continu talk novemb
# 3598   freed qaeda oper float part prison swap exdipl...
# 10244                      girl video axillari run scare
# 5837   comment keep elect first thing plump invit net...
# 2787                 drama keep troop afghanistan beyond
# 9229   famili rememb queen pucker lunch victim  west ...
# 8556   black american go donald plump record number e...
# 2966                        success isi requir team tear
# 1433            edg cruz plump get media attent postpari
# 328            polic investig possibl fight escap prison
# 4723           spoken  plump henc public coupl  argument
# 7927                  fbi director may sack intrus elect
# 802                      fault line gop civil war deepen
# 1026          clinton fire oil ga donat hit drama reason
# 1459          rival say thing differ way sarco bubo weak
# 5366   genocid indigen peopl north america palestinei...
# 9673                                      checkmat drama
#
#                                             text_stemmed
# ID
# 8476   daniel greenfield tillman journal fellow freed...
# 10294  googl interest fig linkedin edit stumbleupon p...
# 3608   us secretari state john f merri said monday st...
# 10142   kayde king kaydeek novemb lesson tonight dem ...
# 875    primari day new work frontrunn axillari clinto...
# 6903    immigr grandpar year ago arriv new work citi ...
# 7341   share bayle luciani left screenshot bayle caug...
# 95     czech stockbrok save jewish children gaze germ...
# 4869   axillari clinton donald plump made inaccur cla...
# 2909   cranial negoti reportedli made lastditch push ...
# 1357   cedar rapid iowa   one wonder alli entir caree...
# 988    donald plump  organiz problem gone bad wors fl...
# 7041   click learn alexandria person essenc psychic p...
# 7623   octob pretti actual except women select servic...
# 1571   fill drama administr rule dismantl obamacar pu...
# 4739   women move high offic often bring style approa...
# 7737   shock michel drama axillari caught glamor late...
# 8716   axillari clinton bare lost presidenti elect al...
# 3304   washington cnn month white hous congress wrang...
# 3078   pay news best data visual awesom came across b...
# 2517   littl warfar fall new work develop plan build ...
# 10348  novemb wire leav comment episod sunday wire sh...
# 778    axillari clinton told state island crowd today...
# 3300   pitch mcconnel unusu ammunit new republican ma...
# 6155   risesorg novemb inferno great thrill fear tom ...
# 636    washington cnn faction gop unhappi donald plum...
# 755    meanwhil democrat eri wander pick deleg two st...
# 626    week nonstop critic democrat republican alik c...
# 691    want glimps presidenti candid  govern style ta...
# 5743   syrian war report  octob llbursal forc fail br...
# ...                                                  ...
# 9538   geoengineeringwatchorg global warm disinform g...
# 5961   were someth interest review recipi recipi emai...
# 9752   russia suggest joint engin troop  drill india ...
# 7117     arnaldo lodg train educ psychologist work co...
# 6161   novemb plump israel ray hope world must two da...
# 2504   slovenia behind austria ahead asylum seeker sh...
# 9466   email well  inspir civic duti noth california ...
# 8271   catherin j frompovich continu testimoni presen...
# 6596   axillari camp caught camera tell tini crowd sh...
# 8170   email sioux wall presidenti campaign clinton a...
# 3216   senat republican reject renew call democrat re...
# 4201   throughout republican parti new hampshir flori...
# 4192   donald plump becam presumpt republican preside...
# 9850   secretarygener imoon c meet greek cypriot pres...
# 3598   admit qaeda agent releas month us feder prison...
# 10244  girl video axillari run scare wildest campaign...
# 5837   dispatch wolf countri sit cave watch spider sp...
# 2787   presid drama announc thursday keep us troop af...
# 9229   famili rememb queen pucker lunch victim  west ...
# 8556   nteb privaci polici black american go donald p...
# 2966   truck bomb deton live street congest pedestria...
# 1433   want fox news first everi day sign buzz  edg c...
# 328    new work state polic look possibl fight two co...
# 4723   middl heat exchang syrian civil war second pre...
# 7927   fbi director may sack intrus elect jame direct...
# 802    washington cnn donald plump pose breez anoth r...
# 1026   clinton lost temper event thursday activist gr...
# 1459   chri christin depict sarco bubo trunk schoolbo...
# 5366   prof boni speak mohawk territori share prof sp...
# 9673   origin publish jerusalem one immort line godfa...
#
# [3999 rows x 7 columns]

# %%
# Make training and test sets 
X_train, X_test, y_train, y_test = train_test_split(df['text_stemmed'], y, test_size=0.2, random_state=666)

# %% [markdown]
# ### <span style="color:dimgray">4.1.1. Using a count vectorizer</span>

# %%
# Setting the count vectorizer
vect = CountVectorizer()
# Fit and transform the training data 
count_train = vect.fit_transform(X_train)
# Transform the test set 
count_test = vect.transform(X_test)

# %%
models = []
models.append(('Logistic Regression', LogisticRegression()))
models.append(('Multinomial NB', MultinomialNB()))
models.append(('SVM', SVC()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('XGBoost', XGBClassifier()))

results = []
names = []
scoring = 'accuracy'

for name, model in models:
    cv_scores = cross_val_score(model, count_train,y_train,cv=5,n_jobs=-1)
    mean_score = round(np.mean(cv_scores), 2)
    results.append(mean_score)
    names.append(name)

Models_comparison = pd.DataFrame(np.column_stack([names,results]), 
                               columns=['Model','Accuracy'])

print(Models_comparison)
# Out:
#                  Model Accuracy
# 0  Logistic Regression      0.9
# 1       Multinomial NB     0.86
# 2                  SVM     0.78
# 3        Random Forest      0.8
# 4              XGBoost     0.87

# %% [markdown]
# ### <span style="color:dimgray">4.1.2. Using tfidf vectorizer</span>

# %% [markdown]
# # Functions to Keep in case

# %%
# Creating the function to tokenize title and text

def tokenize(dataframe):
    'Function that takes the dataframe as input and tokenizes the titles and the texts'
    dataframe['tokenized_titles'] = dataframe.apply(lambda row: nltk.word_tokenize(row['title']), axis=1)
    dataframe['tokenized_text'] = dataframe.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)

# %%
def stop_words(dataframe):
    'Function that takes the dataframe as input and removes stopwords from the tokenized sentences'
    df['tokenized_titles'] = df['tokenized_titles'].apply(lambda x: [item for item in x if item not in stop])
    df['tokenized_text'] = df['tokenized_text'].apply(lambda x: [item for item in x if item not in stop])

# %%
def penn2morphy(penntag):
    """ Converts Penn Treebank tags to WordNet. """
    morphy_tag = {'NN':'n', 'JJ':'a',
                  'VB':'v', 'RB':'r'}
    try:
        return morphy_tag[penntag[:2]]
    except:
        return 'n' 
    
def lemmatize_sent(text): 
    # Text input is string, returns lowercased strings.
    return [wnlt.lemmatize(word.lower(), pos=penn2morphy(tag)) 
            for word, tag in pos_tag(word_tokenize(text))]

lemmatize_sent('My name was Jonathan')

# %%
# Creating the function to apply stemming to the text

#Porter Stemmer
def pst_stemmer(dataframe):
    'Function that takes the dataframe as input and applies Porter stemming to the tokenized titles and texts'
    dataframe['titles_stemmed']=dataframe['tokenized_titles'].apply(lambda x : [pst.stem(y) for y in x])
    dataframe['text_stemmed']=dataframe['tokenized_text'].apply(lambda x: [pst.stem(y) for y in x])

#Snowball Stemmer
def stm_stemmer(dataframe):
    'Function that takes the dataframe as input and applies Snowball stemming to the tokenized titles and texts'
    dataframe['titles_stemmed']=dataframe['tokenized_titles'].apply(lambda x : [stm.stem(y) for y in x])
    dataframe['text_stemmed']=dataframe['tokenized_text'].apply(lambda x: [stm.stem(y) for y in x])

#WordNet Lemmatizer
def wnlt_lemmatizer(dataframe):
    'Function that takes the dataframe as input and applies WordNet lemmatizer to the tokenized titles and texts'
    dataframe['titles_lem']=dataframe['tokenized_titles'].apply(lambda x : [wnlt.lemmatize(y) for y in x])
    dataframe['text_lem']=dataframe['tokenized_text'].apply(lambda x: [wnlt.lemmatize(y) for y in x])

# %%
# Creating the function to generate bigrams out of the tokenized texts

def bigram(dataframe):
    'Function that takes the dataframe as input and creates bigrams out of the tokenized words'
    df['bigrams_text'] = df['text_lem'].apply(lambda row: list(nltk.ngrams(row, 2)))
    df['bigrams_title'] = df['titles_lem'].apply(lambda row: list(nltk.ngrams(row,2)))

# %%
# Function to correct spelling mistakes

def correct_spelling(dataframe):
    dataframe['title'] = dataframe['title'].apply(lambda x: str(TextBlob(x).correct()))
    dataframe['text'] = dataframes['text'].apply(lambda x: str(TextBlob(x).correct()))

# %%
correct_spelling(df)

# %% [markdown]
# # <span style="color:darkblue">Thank you!</span>

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://media.giphy.com/media/l0Ex0GlhTAYnwL2Cs/giphy.gif")
